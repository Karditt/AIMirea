# %% [markdown]
# Задание
#
# Создайте класс по работе с тригонометрическими функциями. В классе должны быть реализованы функции вычисления:
#
# − косинуса;
#
# − синуса;
#
# − тангенса;
#
# − арксинуса;
#
# − арккосинуса;
#
# − арктангенса;
#
# − перевода из градусов в радианы.

# %%
import math

class Trigonom:
    
    def cos(a):
        return math.cos(a)
    
    def sin(a):
        return math.sin(a)
    
    def tan(a):
        return math.tan(a)
    
    def asin(a):
        return math.asin(a)
    
    def acos(a):
        return math.acos(a)
    
    def atan(a):
        return math.atan(a)
    
    def rad(a):
        return a*math.pi/180

print(Trigonom.cos(1))
print(Trigonom.sin(5))
print(Trigonom.tan(2))
print(Trigonom.asin(0.5))
print(Trigonom.acos(1))
print(Trigonom.atan(1))
print(Trigonom.rad(45))
# Out:
# 0.5403023058681398
# -0.9589242746631385
# -2.185039863261519
# 0.5235987755982989
# 0.0
# 0.7853981633974483
# 0.7853981633974483

# %% [markdown]
# Задание
#
# Представьте дерево показанное на рисунке с использованием списка из списков. Выведите на печать корень дерева, а также его левое и правое поддеревья.

# %%
T = ["a",["b", ["d", "e"]], ["c", ["f"]]]
print("Корень: ", T[0])
print("Левое поддерево: ", T[1][0], T[1][1][0], T[1][1][1])
print("Правое поддерево: ", T[2][0], T[2][1][0])
# Out:
# Корень:  a
# Левое поддерево:  b d e
# Правое поддерево:  c f

# %% [markdown]
# Задание
#
# Дан класс, описывающий бинарное дерево
# ```
# class Tree:
#   def __init__(self, data):
#     self.left = None
#     self.right = None
#     self.data = data
#   def PrintTree(self):
#     print(self.data)
# ```
# Реализуйте в классе функцию для вставки нового элемента в дерево по следующим правилам:
#
# • Левое поддерево узла содержит только узлы со значениями меньше, чем значение в узле.
#
# • Правое поддерево узла содержит только узлы со значениями меньше, чем значение в узле.
#
# • Каждое из левого и правого поддеревьев также должно быть бинарным деревом поиска.
#
# • Не должно быть повторяющихся узлов.
#
# Метод вставки сравнивает значение узла с родительским узлом и решает куда доваить элемент (в левое или правое PrintTree для печати полной версии дерева.

# %%
class Node:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

    def insert(self, data):
        if self.data:
            if data < self.data:
                if self.left is None:
                    self.left = Node(data)
                else:
                    self.left.insert(data)
            if data > self.data:
                if self.right is None:
                    self.right = Node(data)
                else:
                    self.right.insert(data)
        else:
            self.data = data

    def PrintTree(self):
        if self.left:
            self.left.PrintTree()
        print(self.data),
        if self.right:
            self.right.PrintTree()

root = Node(12)
root.insert(6)
root.insert(14)
root.insert(3)
root.PrintTree()
# Out:
# 3
# 6
# 12
# 14

# %% [markdown]
# Задание
#
# Постройте классификатор на основе дерева принятия решений следующего датасета:
#
# ```
# X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
# target = [0, 0, 0, 1, 1, 1]
# ```

# %%
from sklearn.utils.multiclass import type_of_target
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
target = [0, 0, 0, 1, 1, 1]

new_y = np.array(target)
new_y = new_y.transpose()
df1 = pd.DataFrame(new_y)
df2 = pd.DataFrame(X)
df1 = df1.rename(columns = {0: 'target'}, inplace = False)
df2 = df2.rename(columns = {0: 'x1', 1: 'x2'}, inplace = False)

frames = [df1, df2]
dataset = pd.concat([df1, df2], axis=1, join="inner")
dataset
# Out:
#    target  x1  x2
# 0       0  -1  -1
# 1       0  -2  -1
# 2       0  -3  -2
# 3       1   1   1
# 4       1   2   1
# 5       1   3   2

# %%
dataset.shape
# Out:
# (6, 3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    # поскольку iris это pandas-таблица, для нее нужно указывать iloc
    dataset.iloc[:, : -1], # берем все колонки кроме последней в признаки
    dataset.iloc[:, -1], # последнюю в целевую переменную (класс)
    test_size = 0.20 # размер тестовой выборки 20%
)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4, 2), (2, 2), (4,), (2,))

# %%
X_train.head()
# Out:
#    target  x1
# 3       1   1
# 5       1   3
# 2       0  -3
# 1       0  -2

# %%
y_train.head()
# Out:
# 3    1
# 5    2
# 2   -2
# 1   -1
# Name: x2, dtype: int32

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
tree.plot_tree(classifier)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= 0.5\ngini = 0.75\nsamples = 4\nvalue = [1, 1, 1, 1]'),
#  Text(0.25, 0.5, 'x[1] <= -2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.75, 0.5, 'x[1] <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]')]

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([-1,  1])

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1 0]
#  [0 1]]
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %% [markdown]
# Задание
#
# Задание. Постройте модель регрессии для данных из предыдущей рабочей тетради.Для примера можно взять потребления газа (в миллионах галлонов) в 48 штатах США или набор данных о качестве красного вина: https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/pet rol_consumption.csv https://raw.githubusercontent.com/aniruddhachoudhury/Red-WineQuality/master/winequality-red.csv Постройте прогноз. Оцените точность модели.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = r'https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv'
dataset = pd.read_csv(url)
dataset.head()

print(dataset.shape)
dataset.describe()
# Out:
# (1599, 12)
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
from sklearn.tree import DecisionTreeRegressor
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values
print(X)
print(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
# Out:
# [[ 7.4    0.7    0.    ...  3.51   0.56   9.4  ]
#  [ 7.8    0.88   0.    ...  3.2    0.68   9.8  ]
#  [ 7.8    0.76   0.04  ...  3.26   0.65   9.8  ]
#  ...
#  [ 6.3    0.51   0.13  ...  3.42   0.75  11.   ]
#  [ 5.9    0.645  0.12  ...  3.57   0.71  10.2  ]
#  [ 6.     0.31   0.47  ...  3.39   0.66  11.   ]]
# [0.7   0.88  0.76  ... 0.51  0.645 0.31 ]
# DecisionTreeRegressor()

# %%
from sklearn import tree
tree.plot_tree(regressor)
# Out:
# [Text(0.4168119635193133, 0.9615384615384616, 'x[1] <= 0.535\nsquared_error = 0.033\nsamples = 1279\nvalue = 0.53'),
#  Text(0.17060085836909872, 0.8846153846153846, 'x[1] <= 0.375\nsquared_error = 0.008\nsamples = 666\nvalue = 0.392'),
#  Text(0.0890557939914163, 0.8076923076923077, 'x[1] <= 0.285\nsquared_error = 0.003\nsamples = 263\nvalue = 0.301'),
#  Text(0.043991416309012876, 0.7307692307692307, 'x[1] <= 0.225\nsquared_error = 0.002\nsamples = 90\nvalue = 0.24'),
#  Text(0.019313304721030045, 0.6538461538461539, 'x[1] <= 0.17\nsquared_error = 0.001\nsamples = 25\nvalue = 0.186'),
#  Text(0.008583690987124463, 0.5769230769230769, 'x[0] <= 8.0\nsquared_error = 0.0\nsamples = 4\nvalue = 0.13'),
#  Text(0.004291845493562232, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 0.16'),
#  Text(0.012875536480686695, 0.5, 'squared_error = 0.0\nsamples = 3\nvalue = 0.12'),
#  Text(0.030042918454935622, 0.5769230769230769, 'x[1] <= 0.195\nsquared_error = 0.0\nsamples = 21\nvalue = 0.197'),
#  Text(0.02145922746781116, 0.5, 'x[1] <= 0.185\nsquared_error = 0.0\nsamples = 10\nvalue = 0.182'),
#  Text(0.017167381974248927, 0.4230769230769231, 'squared_error = 0.0\nsamples = 8\nvalue = 0.18'),
#  Text(0.02575107296137339, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.19'),
#  Text(0.03862660944206009, 0.5, 'x[1] <= 0.215\nsquared_error = 0.0\nsamples = 11\nvalue = 0.211'),
#  Text(0.034334763948497854, 0.4230769230769231, 'x[1] <= 0.205\nsquared_error = 0.0\nsamples = 7\nvalue = 0.206'),
#  Text(0.030042918454935622, 0.34615384615384615, 'squared_error = -0.0\nsamples = 3\nvalue = 0.2'),
#  Text(0.03862660944206009, 0.34615384615384615, 'squared_error = 0.0\nsamples = 4\nvalue = 0.21'),
#  Text(0.04291845493562232, 0.4230769230769231, 'squared_error = -0.0\nsamples = 4\nvalue = 0.22'),
#  Text(0.06866952789699571, 0.6538461538461539, 'x[1] <= 0.255\nsquared_error = 0.0\nsamples = 65\nvalue = 0.26'),
#  Text(0.060085836909871244, 0.5769230769230769, 'x[1] <= 0.245\nsquared_error = 0.0\nsamples = 23\nvalue = 0.241'),
#  Text(0.055793991416309016, 0.5, 'x[1] <= 0.235\nsquared_error = 0.0\nsamples = 16\nvalue = 0.237'),
#  Text(0.05150214592274678, 0.4230769230769231, 'squared_error = -0.0\nsamples = 5\nvalue = 0.23'),
#  Text(0.060085836909871244, 0.4230769230769231, 'squared_error = -0.0\nsamples = 11\nvalue = 0.24'),
#  Text(0.06437768240343347, 0.5, 'squared_error = 0.0\nsamples = 7\nvalue = 0.25'),
#  Text(0.07725321888412018, 0.5769230769230769, 'x[1] <= 0.275\nsquared_error = 0.0\nsamples = 42\nvalue = 0.271'),
#  Text(0.07296137339055794, 0.5, 'x[1] <= 0.265\nsquared_error = 0.0\nsamples = 23\nvalue = 0.264'),
#  Text(0.06866952789699571, 0.4230769230769231, 'squared_error = -0.0\nsamples = 14\nvalue = 0.26'),
#  Text(0.07725321888412018, 0.4230769230769231, 'squared_error = 0.0\nsamples = 9\nvalue = 0.27'),
#  Text(0.0815450643776824, 0.5, 'squared_error = 0.0\nsamples = 19\nvalue = 0.28'),
#  Text(0.13412017167381973, 0.7307692307692307, 'x[1] <= 0.335\nsquared_error = 0.001\nsamples = 173\nvalue = 0.333'),
#  Text(0.11373390557939914, 0.6538461538461539, 'x[1] <= 0.312\nsquared_error = 0.0\nsamples = 86\nvalue = 0.311'),
#  Text(0.09871244635193133, 0.5769230769230769, 'x[1] <= 0.303\nsquared_error = 0.0\nsamples = 50\nvalue = 0.302'),
#  Text(0.09012875536480687, 0.5, 'x[1] <= 0.295\nsquared_error = 0.0\nsamples = 26\nvalue = 0.295'),
#  Text(0.08583690987124463, 0.4230769230769231, 'squared_error = -0.0\nsamples = 12\nvalue = 0.29'),
#  Text(0.0944206008583691, 0.4230769230769231, 'squared_error = 0.0\nsamples = 14\nvalue = 0.3'),
#  Text(0.1072961373390558, 0.5, 'x[3] <= 1.3\nsquared_error = 0.0\nsamples = 24\nvalue = 0.31'),
#  Text(0.10300429184549356, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.305'),
#  Text(0.11158798283261803, 0.4230769230769231, 'squared_error = 0.0\nsamples = 22\nvalue = 0.31'),
#  Text(0.12875536480686695, 0.5769230769230769, 'x[1] <= 0.325\nsquared_error = 0.0\nsamples = 36\nvalue = 0.324'),
#  Text(0.12446351931330472, 0.5, 'x[1] <= 0.317\nsquared_error = 0.0\nsamples = 20\nvalue = 0.32'),
#  Text(0.12017167381974249, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.315'),
#  Text(0.12875536480686695, 0.4230769230769231, 'squared_error = -0.0\nsamples = 18\nvalue = 0.32'),
#  Text(0.13304721030042918, 0.5, 'squared_error = -0.0\nsamples = 16\nvalue = 0.33'),
#  Text(0.15450643776824036, 0.6538461538461539, 'x[1] <= 0.355\nsquared_error = 0.0\nsamples = 87\nvalue = 0.355'),
#  Text(0.1459227467811159, 0.5769230769230769, 'x[1] <= 0.345\nsquared_error = 0.0\nsamples = 39\nvalue = 0.345'),
#  Text(0.14163090128755365, 0.5, 'squared_error = -0.0\nsamples = 21\nvalue = 0.34'),
#  Text(0.15021459227467812, 0.5, 'x[3] <= 1.7\nsquared_error = 0.0\nsamples = 18\nvalue = 0.35'),
#  Text(0.1459227467811159, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.35'),
#  Text(0.15450643776824036, 0.4230769230769231, 'squared_error = 0.0\nsamples = 17\nvalue = 0.35'),
#  Text(0.1630901287553648, 0.5769230769230769, 'x[1] <= 0.363\nsquared_error = 0.0\nsamples = 48\nvalue = 0.364'),
#  Text(0.15879828326180256, 0.5, 'squared_error = 0.0\nsamples = 29\nvalue = 0.36'),
#  Text(0.16738197424892703, 0.5, 'x[8] <= 3.35\nsquared_error = 0.0\nsamples = 19\nvalue = 0.37'),
#  Text(0.1630901287553648, 0.4230769230769231, 'squared_error = -0.0\nsamples = 18\nvalue = 0.37'),
#  Text(0.17167381974248927, 0.4230769230769231, 'squared_error = -0.0\nsamples = 1\nvalue = 0.365'),
#  Text(0.2521459227467811, 0.8076923076923077, 'x[1] <= 0.455\nsquared_error = 0.002\nsamples = 403\nvalue = 0.451'),
#  Text(0.2145922746781116, 0.7307692307692307, 'x[1] <= 0.412\nsquared_error = 0.0\nsamples = 217\nvalue = 0.413'),
#  Text(0.19742489270386265, 0.6538461538461539, 'x[1] <= 0.395\nsquared_error = 0.0\nsamples = 113\nvalue = 0.394'),
#  Text(0.1888412017167382, 0.5769230769230769, 'x[1] <= 0.385\nsquared_error = 0.0\nsamples = 59\nvalue = 0.385'),
#  Text(0.18454935622317598, 0.5, 'x[2] <= 0.1\nsquared_error = 0.0\nsamples = 31\nvalue = 0.38'),
#  Text(0.18025751072961374, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.38'),
#  Text(0.1888412017167382, 0.4230769230769231, 'squared_error = -0.0\nsamples = 29\nvalue = 0.38'),
#  Text(0.19313304721030042, 0.5, 'squared_error = -0.0\nsamples = 28\nvalue = 0.39'),
#  Text(0.20600858369098712, 0.5769230769230769, 'x[1] <= 0.405\nsquared_error = 0.0\nsamples = 54\nvalue = 0.405'),
#  Text(0.2017167381974249, 0.5, 'squared_error = 0.0\nsamples = 28\nvalue = 0.4'),
#  Text(0.21030042918454936, 0.5, 'squared_error = -0.0\nsamples = 26\nvalue = 0.41'),
#  Text(0.2317596566523605, 0.6538461538461539, 'x[1] <= 0.435\nsquared_error = 0.0\nsamples = 104\nvalue = 0.433'),
#  Text(0.22317596566523606, 0.5769230769230769, 'x[1] <= 0.425\nsquared_error = 0.0\nsamples = 66\nvalue = 0.425'),
#  Text(0.21888412017167383, 0.5, 'x[1] <= 0.417\nsquared_error = 0.0\nsamples = 29\nvalue = 0.42'),
#  Text(0.2145922746781116, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.415'),
#  Text(0.22317596566523606, 0.4230769230769231, 'squared_error = 0.0\nsamples = 27\nvalue = 0.42'),
#  Text(0.22746781115879827, 0.5, 'squared_error = -0.0\nsamples = 37\nvalue = 0.43'),
#  Text(0.24034334763948498, 0.5769230769230769, 'x[1] <= 0.445\nsquared_error = 0.0\nsamples = 38\nvalue = 0.445'),
#  Text(0.23605150214592274, 0.5, 'squared_error = -0.0\nsamples = 20\nvalue = 0.44'),
#  Text(0.2446351931330472, 0.5, 'x[10] <= 9.4\nsquared_error = 0.0\nsamples = 18\nvalue = 0.45'),
#  Text(0.24034334763948498, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.45'),
#  Text(0.24892703862660945, 0.4230769230769231, 'squared_error = 0.0\nsamples = 17\nvalue = 0.45'),
#  Text(0.28969957081545067, 0.7307692307692307, 'x[1] <= 0.495\nsquared_error = 0.001\nsamples = 186\nvalue = 0.495'),
#  Text(0.2703862660944206, 0.6538461538461539, 'x[1] <= 0.472\nsquared_error = 0.0\nsamples = 94\nvalue = 0.476'),
#  Text(0.2575107296137339, 0.5769230769230769, 'x[1] <= 0.465\nsquared_error = 0.0\nsamples = 42\nvalue = 0.464'),
#  Text(0.2532188841201717, 0.5, 'squared_error = -0.0\nsamples = 27\nvalue = 0.46'),
#  Text(0.26180257510729615, 0.5, 'x[8] <= 3.12\nsquared_error = 0.0\nsamples = 15\nvalue = 0.47'),
#  Text(0.2575107296137339, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.47'),
#  Text(0.26609442060085836, 0.4230769230769231, 'squared_error = 0.0\nsamples = 13\nvalue = 0.47'),
#  Text(0.2832618025751073, 0.5769230769230769, 'x[1] <= 0.485\nsquared_error = 0.0\nsamples = 52\nvalue = 0.485'),
#  Text(0.27896995708154504, 0.5, 'x[1] <= 0.477\nsquared_error = 0.0\nsamples = 23\nvalue = 0.48'),
#  Text(0.27467811158798283, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.475'),
#  Text(0.2832618025751073, 0.4230769230769231, 'squared_error = -0.0\nsamples = 21\nvalue = 0.48'),
#  Text(0.2875536480686695, 0.5, 'squared_error = 0.0\nsamples = 29\nvalue = 0.49'),
#  Text(0.3090128755364807, 0.6538461538461539, 'x[1] <= 0.515\nsquared_error = 0.0\nsamples = 92\nvalue = 0.514'),
#  Text(0.30042918454935624, 0.5769230769230769, 'x[1] <= 0.505\nsquared_error = 0.0\nsamples = 46\nvalue = 0.504'),
#  Text(0.296137339055794, 0.5, 'x[9] <= 0.46\nsquared_error = 0.0\nsamples = 28\nvalue = 0.5'),
#  Text(0.2918454935622318, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.5'),
#  Text(0.30042918454935624, 0.4230769230769231, 'squared_error = 0.0\nsamples = 26\nvalue = 0.5'),
#  Text(0.30472103004291845, 0.5, 'squared_error = -0.0\nsamples = 18\nvalue = 0.51'),
#  Text(0.31759656652360513, 0.5769230769230769, 'x[1] <= 0.525\nsquared_error = 0.0\nsamples = 46\nvalue = 0.525'),
#  Text(0.3133047210300429, 0.5, 'x[8] <= 2.945\nsquared_error = 0.0\nsamples = 24\nvalue = 0.52'),
#  Text(0.3090128755364807, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.52'),
#  Text(0.31759656652360513, 0.4230769230769231, 'x[10] <= 9.05\nsquared_error = 0.0\nsamples = 23\nvalue = 0.52'),
#  Text(0.3133047210300429, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.52'),
#  Text(0.3218884120171674, 0.34615384615384615, 'x[5] <= 4.5\nsquared_error = 0.0\nsamples = 21\nvalue = 0.52'),
#  Text(0.31759656652360513, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.52'),
#  Text(0.3261802575107296, 0.2692307692307692, 'x[7] <= 0.994\nsquared_error = 0.0\nsamples = 20\nvalue = 0.52'),
#  Text(0.3218884120171674, 0.19230769230769232, 'squared_error = 0.0\nsamples = 2\nvalue = 0.52'),
#  Text(0.33047210300429186, 0.19230769230769232, 'x[2] <= 0.035\nsquared_error = 0.0\nsamples = 18\nvalue = 0.52'),
#  Text(0.3261802575107296, 0.11538461538461539, 'squared_error = 0.0\nsamples = 2\nvalue = 0.52'),
#  Text(0.33476394849785407, 0.11538461538461539, 'x[9] <= 0.5\nsquared_error = 0.0\nsamples = 16\nvalue = 0.52'),
#  Text(0.33047210300429186, 0.038461538461538464, 'squared_error = 0.0\nsamples = 1\nvalue = 0.52'),
#  Text(0.33905579399141633, 0.038461538461538464, 'squared_error = 0.0\nsamples = 15\nvalue = 0.52'),
#  Text(0.3218884120171674, 0.5, 'squared_error = -0.0\nsamples = 22\nvalue = 0.53'),
#  Text(0.6630230686695279, 0.8846153846153846, 'x[1] <= 0.762\nsquared_error = 0.018\nsamples = 613\nvalue = 0.68'),
#  Text(0.46405579399141633, 0.8076923076923077, 'x[1] <= 0.637\nsquared_error = 0.003\nsamples = 494\nvalue = 0.628'),
#  Text(0.3927038626609442, 0.7307692307692307, 'x[1] <= 0.587\nsquared_error = 0.001\nsamples = 293\nvalue = 0.587'),
#  Text(0.3605150214592275, 0.6538461538461539, 'x[1] <= 0.562\nsquared_error = 0.0\nsamples = 137\nvalue = 0.561'),
#  Text(0.34763948497854075, 0.5769230769230769, 'x[1] <= 0.555\nsquared_error = 0.0\nsamples = 78\nvalue = 0.55'),
#  Text(0.34334763948497854, 0.5, 'x[1] <= 0.543\nsquared_error = 0.0\nsamples = 49\nvalue = 0.544'),
#  Text(0.33476394849785407, 0.4230769230769231, 'x[3] <= 2.25\nsquared_error = 0.0\nsamples = 28\nvalue = 0.54'),
#  Text(0.33047210300429186, 0.34615384615384615, 'squared_error = -0.0\nsamples = 13\nvalue = 0.54'),
#  Text(0.33905579399141633, 0.34615384615384615, 'x[3] <= 3.2\nsquared_error = 0.0\nsamples = 15\nvalue = 0.54'),
#  Text(0.33476394849785407, 0.2692307692307692, 'squared_error = -0.0\nsamples = 11\nvalue = 0.54'),
#  Text(0.34334763948497854, 0.2692307692307692, 'squared_error = -0.0\nsamples = 4\nvalue = 0.54'),
#  Text(0.351931330472103, 0.4230769230769231, 'x[1] <= 0.548\nsquared_error = 0.0\nsamples = 21\nvalue = 0.549'),
#  Text(0.34763948497854075, 0.34615384615384615, 'squared_error = 0.0\nsamples = 5\nvalue = 0.545'),
#  Text(0.3562231759656652, 0.34615384615384615, 'squared_error = 0.0\nsamples = 16\nvalue = 0.55'),
#  Text(0.351931330472103, 0.5, 'squared_error = -0.0\nsamples = 29\nvalue = 0.56'),
#  Text(0.37339055793991416, 0.5769230769230769, 'x[1] <= 0.577\nsquared_error = 0.0\nsamples = 59\nvalue = 0.576'),
#  Text(0.3648068669527897, 0.5, 'x[10] <= 9.25\nsquared_error = 0.0\nsamples = 27\nvalue = 0.57'),
#  Text(0.3605150214592275, 0.4230769230769231, 'squared_error = 0.0\nsamples = 3\nvalue = 0.575'),
#  Text(0.36909871244635195, 0.4230769230769231, 'x[1] <= 0.567\nsquared_error = 0.0\nsamples = 24\nvalue = 0.57'),
#  Text(0.3648068669527897, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.565'),
#  Text(0.37339055793991416, 0.34615384615384615, 'squared_error = -0.0\nsamples = 23\nvalue = 0.57'),
#  Text(0.38197424892703863, 0.5, 'x[1] <= 0.582\nsquared_error = 0.0\nsamples = 32\nvalue = 0.58'),
#  Text(0.3776824034334764, 0.4230769230769231, 'squared_error = 0.0\nsamples = 29\nvalue = 0.58'),
#  Text(0.38626609442060084, 0.4230769230769231, 'squared_error = -0.0\nsamples = 3\nvalue = 0.585'),
#  Text(0.4248927038626609, 0.6538461538461539, 'x[1] <= 0.613\nsquared_error = 0.0\nsamples = 156\nvalue = 0.609'),
#  Text(0.40772532188841204, 0.5769230769230769, 'x[1] <= 0.598\nsquared_error = 0.0\nsamples = 95\nvalue = 0.599'),
#  Text(0.39914163090128757, 0.5, 'x[3] <= 7.55\nsquared_error = 0.0\nsamples = 30\nvalue = 0.59'),
#  Text(0.3948497854077253, 0.4230769230769231, 'squared_error = 0.0\nsamples = 29\nvalue = 0.59'),
#  Text(0.4034334763948498, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.595'),
#  Text(0.41630901287553645, 0.5, 'x[1] <= 0.603\nsquared_error = 0.0\nsamples = 65\nvalue = 0.603'),
#  Text(0.41201716738197425, 0.4230769230769231, 'squared_error = -0.0\nsamples = 41\nvalue = 0.6'),
#  Text(0.4206008583690987, 0.4230769230769231, 'x[1] <= 0.608\nsquared_error = 0.0\nsamples = 24\nvalue = 0.609'),
#  Text(0.41630901287553645, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.605'),
#  Text(0.4248927038626609, 0.34615384615384615, 'squared_error = -0.0\nsamples = 21\nvalue = 0.61'),
#  Text(0.44206008583690987, 0.5769230769230769, 'x[1] <= 0.627\nsquared_error = 0.0\nsamples = 61\nvalue = 0.625'),
#  Text(0.4334763948497854, 0.5, 'x[1] <= 0.618\nsquared_error = 0.0\nsamples = 30\nvalue = 0.62'),
#  Text(0.4291845493562232, 0.4230769230769231, 'squared_error = 0.0\nsamples = 5\nvalue = 0.615'),
#  Text(0.43776824034334766, 0.4230769230769231, 'x[1] <= 0.623\nsquared_error = 0.0\nsamples = 25\nvalue = 0.621'),
#  Text(0.4334763948497854, 0.34615384615384615, 'x[2] <= 0.02\nsquared_error = 0.0\nsamples = 22\nvalue = 0.62'),
#  Text(0.4291845493562232, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.62'),
#  Text(0.43776824034334766, 0.2692307692307692, 'x[6] <= 45.5\nsquared_error = 0.0\nsamples = 21\nvalue = 0.62'),
#  Text(0.4334763948497854, 0.19230769230769232, 'squared_error = -0.0\nsamples = 8\nvalue = 0.62'),
#  Text(0.44206008583690987, 0.19230769230769232, 'x[8] <= 3.115\nsquared_error = 0.0\nsamples = 13\nvalue = 0.62'),
#  Text(0.43776824034334766, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 0.62'),
#  Text(0.44635193133047213, 0.11538461538461539, 'squared_error = 0.0\nsamples = 12\nvalue = 0.62'),
#  Text(0.44206008583690987, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.625'),
#  Text(0.45064377682403434, 0.5, 'x[1] <= 0.632\nsquared_error = 0.0\nsamples = 31\nvalue = 0.631'),
#  Text(0.44635193133047213, 0.4230769230769231, 'squared_error = -0.0\nsamples = 25\nvalue = 0.63'),
#  Text(0.45493562231759654, 0.4230769230769231, 'squared_error = -0.0\nsamples = 6\nvalue = 0.635'),
#  Text(0.5354077253218884, 0.7307692307692307, 'x[1] <= 0.697\nsquared_error = 0.001\nsamples = 201\nvalue = 0.687'),
#  Text(0.4946351931330472, 0.6538461538461539, 'x[1] <= 0.668\nsquared_error = 0.0\nsamples = 130\nvalue = 0.665'),
#  Text(0.47639484978540775, 0.5769230769230769, 'x[1] <= 0.652\nsquared_error = 0.0\nsamples = 71\nvalue = 0.65'),
#  Text(0.4678111587982833, 0.5, 'x[1] <= 0.642\nsquared_error = 0.0\nsamples = 44\nvalue = 0.644'),
#  Text(0.463519313304721, 0.4230769230769231, 'squared_error = -0.0\nsamples = 20\nvalue = 0.64'),
#  Text(0.4721030042918455, 0.4230769230769231, 'x[1] <= 0.647\nsquared_error = 0.0\nsamples = 24\nvalue = 0.648'),
#  Text(0.4678111587982833, 0.34615384615384615, 'squared_error = -0.0\nsamples = 9\nvalue = 0.645'),
#  Text(0.47639484978540775, 0.34615384615384615, 'squared_error = -0.0\nsamples = 15\nvalue = 0.65'),
#  Text(0.48497854077253216, 0.5, 'x[1] <= 0.657\nsquared_error = 0.0\nsamples = 27\nvalue = 0.659'),
#  Text(0.48068669527896996, 0.4230769230769231, 'squared_error = -0.0\nsamples = 6\nvalue = 0.655'),
#  Text(0.4892703862660944, 0.4230769230769231, 'x[1] <= 0.663\nsquared_error = 0.0\nsamples = 21\nvalue = 0.66'),
#  Text(0.48497854077253216, 0.34615384615384615, 'squared_error = -0.0\nsamples = 19\nvalue = 0.66'),
#  Text(0.49356223175965663, 0.34615384615384615, 'x[6] <= 37.0\nsquared_error = 0.0\nsamples = 2\nvalue = 0.665'),
#  Text(0.4892703862660944, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.665'),
#  Text(0.4978540772532189, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.665'),
#  Text(0.5128755364806867, 0.5769230769230769, 'x[1] <= 0.683\nsquared_error = 0.0\nsamples = 59\nvalue = 0.682'),
#  Text(0.5021459227467812, 0.5, 'x[1] <= 0.673\nsquared_error = 0.0\nsamples = 28\nvalue = 0.674'),
#  Text(0.4978540772532189, 0.4230769230769231, 'squared_error = -0.0\nsamples = 17\nvalue = 0.67'),
#  Text(0.5064377682403434, 0.4230769230769231, 'x[1] <= 0.678\nsquared_error = 0.0\nsamples = 11\nvalue = 0.679'),
#  Text(0.5021459227467812, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.675'),
#  Text(0.5107296137339056, 0.34615384615384615, 'squared_error = 0.0\nsamples = 9\nvalue = 0.68'),
#  Text(0.5236051502145923, 0.5, 'x[1] <= 0.688\nsquared_error = 0.0\nsamples = 31\nvalue = 0.689'),
#  Text(0.51931330472103, 0.4230769230769231, 'squared_error = 0.0\nsamples = 9\nvalue = 0.685'),
#  Text(0.5278969957081545, 0.4230769230769231, 'x[1] <= 0.692\nsquared_error = 0.0\nsamples = 22\nvalue = 0.691'),
#  Text(0.51931330472103, 0.34615384615384615, 'x[4] <= 0.059\nsquared_error = 0.0\nsamples = 17\nvalue = 0.69'),
#  Text(0.5150214592274678, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.69'),
#  Text(0.5236051502145923, 0.2692307692307692, 'squared_error = 0.0\nsamples = 16\nvalue = 0.69'),
#  Text(0.5364806866952789, 0.34615384615384615, 'x[4] <= 0.076\nsquared_error = 0.0\nsamples = 5\nvalue = 0.695'),
#  Text(0.5321888412017167, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.695'),
#  Text(0.5407725321888412, 0.2692307692307692, 'squared_error = 0.0\nsamples = 4\nvalue = 0.695'),
#  Text(0.5761802575107297, 0.6538461538461539, 'x[1] <= 0.728\nsquared_error = 0.0\nsamples = 71\nvalue = 0.728'),
#  Text(0.5536480686695279, 0.5769230769230769, 'x[1] <= 0.712\nsquared_error = 0.0\nsamples = 36\nvalue = 0.713'),
#  Text(0.5450643776824035, 0.5, 'x[1] <= 0.702\nsquared_error = 0.0\nsamples = 14\nvalue = 0.704'),
#  Text(0.5407725321888412, 0.4230769230769231, 'squared_error = -0.0\nsamples = 7\nvalue = 0.7'),
#  Text(0.5493562231759657, 0.4230769230769231, 'x[2] <= 0.025\nsquared_error = 0.0\nsamples = 7\nvalue = 0.707'),
#  Text(0.5450643776824035, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.71'),
#  Text(0.5536480686695279, 0.34615384615384615, 'squared_error = -0.0\nsamples = 4\nvalue = 0.705'),
#  Text(0.5622317596566524, 0.5, 'x[1] <= 0.718\nsquared_error = 0.0\nsamples = 22\nvalue = 0.719'),
#  Text(0.5579399141630901, 0.4230769230769231, 'squared_error = -0.0\nsamples = 10\nvalue = 0.715'),
#  Text(0.5665236051502146, 0.4230769230769231, 'x[1] <= 0.723\nsquared_error = 0.0\nsamples = 12\nvalue = 0.723'),
#  Text(0.5622317596566524, 0.34615384615384615, 'squared_error = 0.0\nsamples = 5\nvalue = 0.72'),
#  Text(0.5708154506437768, 0.34615384615384615, 'x[9] <= 0.51\nsquared_error = 0.0\nsamples = 7\nvalue = 0.725'),
#  Text(0.5665236051502146, 0.2692307692307692, 'squared_error = 0.0\nsamples = 4\nvalue = 0.725'),
#  Text(0.575107296137339, 0.2692307692307692, 'squared_error = -0.0\nsamples = 3\nvalue = 0.725'),
#  Text(0.5987124463519313, 0.5769230769230769, 'x[1] <= 0.743\nsquared_error = 0.0\nsamples = 35\nvalue = 0.743'),
#  Text(0.5879828326180258, 0.5, 'x[1] <= 0.738\nsquared_error = 0.0\nsamples = 20\nvalue = 0.737'),
#  Text(0.5836909871244635, 0.4230769230769231, 'x[8] <= 3.215\nsquared_error = 0.0\nsamples = 10\nvalue = 0.734'),
#  Text(0.5793991416309013, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.73'),
#  Text(0.5879828326180258, 0.34615384615384615, 'squared_error = -0.0\nsamples = 7\nvalue = 0.735'),
#  Text(0.592274678111588, 0.4230769230769231, 'squared_error = 0.0\nsamples = 10\nvalue = 0.74'),
#  Text(0.6094420600858369, 0.5, 'x[1] <= 0.752\nsquared_error = 0.0\nsamples = 15\nvalue = 0.751'),
#  Text(0.6008583690987125, 0.4230769230769231, 'x[1] <= 0.748\nsquared_error = 0.0\nsamples = 10\nvalue = 0.748'),
#  Text(0.5965665236051502, 0.34615384615384615, 'squared_error = 0.0\nsamples = 5\nvalue = 0.745'),
#  Text(0.6051502145922747, 0.34615384615384615, 'squared_error = -0.0\nsamples = 5\nvalue = 0.75'),
#  Text(0.6180257510729614, 0.4230769230769231, 'x[1] <= 0.757\nsquared_error = 0.0\nsamples = 5\nvalue = 0.758'),
#  Text(0.6137339055793991, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.755'),
#  Text(0.6223175965665236, 0.34615384615384615, 'squared_error = -0.0\nsamples = 3\nvalue = 0.76'),
#  Text(0.8619903433476395, 0.8076923076923077, 'x[1] <= 0.955\nsquared_error = 0.017\nsamples = 119\nvalue = 0.899'),
#  Text(0.7623390557939914, 0.7307692307692307, 'x[1] <= 0.848\nsquared_error = 0.002\nsamples = 87\nvalue = 0.837'),
#  Text(0.6952789699570815, 0.6538461538461539, 'x[1] <= 0.805\nsquared_error = 0.001\nsamples = 53\nvalue = 0.804'),
#  Text(0.6609442060085837, 0.5769230769230769, 'x[1] <= 0.782\nsquared_error = 0.0\nsamples = 29\nvalue = 0.782'),
#  Text(0.6437768240343348, 0.5, 'x[1] <= 0.772\nsquared_error = 0.0\nsamples = 15\nvalue = 0.776'),
#  Text(0.6351931330472103, 0.4230769230769231, 'x[9] <= 0.73\nsquared_error = 0.0\nsamples = 5\nvalue = 0.769'),
#  Text(0.630901287553648, 0.34615384615384615, 'squared_error = 0.0\nsamples = 4\nvalue = 0.77'),
#  Text(0.6394849785407726, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.765'),
#  Text(0.6523605150214592, 0.4230769230769231, 'x[1] <= 0.777\nsquared_error = 0.0\nsamples = 10\nvalue = 0.779'),
#  Text(0.648068669527897, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.775'),
#  Text(0.6566523605150214, 0.34615384615384615, 'squared_error = -0.0\nsamples = 8\nvalue = 0.78'),
#  Text(0.6781115879828327, 0.5, 'x[1] <= 0.793\nsquared_error = 0.0\nsamples = 14\nvalue = 0.789'),
#  Text(0.6695278969957081, 0.4230769230769231, 'x[1] <= 0.788\nsquared_error = 0.0\nsamples = 10\nvalue = 0.786'),
#  Text(0.6652360515021459, 0.34615384615384615, 'squared_error = -0.0\nsamples = 8\nvalue = 0.785'),
#  Text(0.6738197424892703, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.79'),
#  Text(0.6866952789699571, 0.4230769230769231, 'x[2] <= 0.055\nsquared_error = 0.0\nsamples = 4\nvalue = 0.798'),
#  Text(0.6824034334763949, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.795'),
#  Text(0.6909871244635193, 0.34615384615384615, 'squared_error = -0.0\nsamples = 2\nvalue = 0.8'),
#  Text(0.7296137339055794, 0.5769230769230769, 'x[1] <= 0.827\nsquared_error = 0.0\nsamples = 24\nvalue = 0.83'),
#  Text(0.7124463519313304, 0.5, 'x[1] <= 0.817\nsquared_error = 0.0\nsamples = 8\nvalue = 0.818'),
#  Text(0.703862660944206, 0.4230769230769231, 'x[4] <= 0.071\nsquared_error = 0.0\nsamples = 4\nvalue = 0.814'),
#  Text(0.6995708154506438, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.81'),
#  Text(0.7081545064377682, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.815'),
#  Text(0.721030042918455, 0.4230769230769231, 'x[5] <= 13.0\nsquared_error = 0.0\nsamples = 4\nvalue = 0.821'),
#  Text(0.7167381974248928, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.825'),
#  Text(0.7253218884120172, 0.34615384615384615, 'squared_error = -0.0\nsamples = 3\nvalue = 0.82'),
#  Text(0.7467811158798283, 0.5, 'x[1] <= 0.837\nsquared_error = 0.0\nsamples = 16\nvalue = 0.837'),
#  Text(0.7381974248927039, 0.4230769230769231, 'x[1] <= 0.832\nsquared_error = 0.0\nsamples = 8\nvalue = 0.832'),
#  Text(0.7339055793991416, 0.34615384615384615, 'squared_error = 0.0\nsamples = 4\nvalue = 0.83'),
#  Text(0.7424892703862661, 0.34615384615384615, 'squared_error = -0.0\nsamples = 4\nvalue = 0.835'),
#  Text(0.7553648068669528, 0.4230769230769231, 'x[1] <= 0.843\nsquared_error = 0.0\nsamples = 8\nvalue = 0.841'),
#  Text(0.7510729613733905, 0.34615384615384615, 'squared_error = -0.0\nsamples = 7\nvalue = 0.84'),
#  Text(0.759656652360515, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 0.845'),
#  Text(0.8293991416309013, 0.6538461538461539, 'x[1] <= 0.892\nsquared_error = 0.001\nsamples = 34\nvalue = 0.888'),
#  Text(0.7982832618025751, 0.5769230769230769, 'x[1] <= 0.868\nsquared_error = 0.0\nsamples = 20\nvalue = 0.87'),
#  Text(0.7811158798283262, 0.5, 'x[1] <= 0.858\nsquared_error = 0.0\nsamples = 8\nvalue = 0.856'),
#  Text(0.7725321888412017, 0.4230769230769231, 'x[6] <= 46.0\nsquared_error = 0.0\nsamples = 5\nvalue = 0.853'),
#  Text(0.7682403433476395, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.855'),
#  Text(0.776824034334764, 0.34615384615384615, 'squared_error = -0.0\nsamples = 2\nvalue = 0.85'),
#  Text(0.7896995708154506, 0.4230769230769231, 'x[10] <= 12.2\nsquared_error = 0.0\nsamples = 3\nvalue = 0.862'),
#  Text(0.7854077253218884, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.86'),
#  Text(0.7939914163090128, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 0.865'),
#  Text(0.8154506437768241, 0.5, 'x[1] <= 0.877\nsquared_error = 0.0\nsamples = 12\nvalue = 0.878'),
#  Text(0.8068669527896996, 0.4230769230769231, 'x[10] <= 10.0\nsquared_error = 0.0\nsamples = 5\nvalue = 0.872'),
#  Text(0.8025751072961373, 0.34615384615384615, 'squared_error = -0.0\nsamples = 3\nvalue = 0.87'),
#  Text(0.8111587982832618, 0.34615384615384615, 'squared_error = -0.0\nsamples = 2\nvalue = 0.875'),
#  Text(0.8240343347639485, 0.4230769230769231, 'x[1] <= 0.882\nsquared_error = 0.0\nsamples = 7\nvalue = 0.883'),
#  Text(0.8197424892703863, 0.34615384615384615, 'squared_error = 0.0\nsamples = 4\nvalue = 0.88'),
#  Text(0.8283261802575107, 0.34615384615384615, 'x[0] <= 10.15\nsquared_error = 0.0\nsamples = 3\nvalue = 0.887'),
#  Text(0.8240343347639485, 0.2692307692307692, 'squared_error = 0.0\nsamples = 2\nvalue = 0.885'),
#  Text(0.8326180257510729, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 0.89'),
#  Text(0.8605150214592274, 0.5769230769230769, 'x[1] <= 0.928\nsquared_error = 0.0\nsamples = 14\nvalue = 0.915'),
#  Text(0.8497854077253219, 0.5, 'x[1] <= 0.905\nsquared_error = 0.0\nsamples = 11\nvalue = 0.908'),
#  Text(0.8412017167381974, 0.4230769230769231, 'x[8] <= 3.515\nsquared_error = 0.0\nsamples = 4\nvalue = 0.899'),
#  Text(0.8369098712446352, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.9'),
#  Text(0.8454935622317596, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.895'),
#  Text(0.8583690987124464, 0.4230769230769231, 'x[3] <= 2.05\nsquared_error = 0.0\nsamples = 7\nvalue = 0.914'),
#  Text(0.8540772532188842, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.91'),
#  Text(0.8626609442060086, 0.34615384615384615, 'x[6] <= 85.5\nsquared_error = 0.0\nsamples = 4\nvalue = 0.916'),
#  Text(0.8583690987124464, 0.2692307692307692, 'squared_error = 0.0\nsamples = 3\nvalue = 0.915'),
#  Text(0.8669527896995708, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.92'),
#  Text(0.871244635193133, 0.5, 'x[1] <= 0.942\nsquared_error = 0.0\nsamples = 3\nvalue = 0.94'),
#  Text(0.8669527896995708, 0.4230769230769231, 'squared_error = -0.0\nsamples = 2\nvalue = 0.935'),
#  Text(0.8755364806866953, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.95'),
#  Text(0.9616416309012875, 0.7307692307692307, 'x[1] <= 1.155\nsquared_error = 0.018\nsamples = 32\nvalue = 1.069'),
#  Text(0.9361587982832618, 0.6538461538461539, 'x[1] <= 1.055\nsquared_error = 0.002\nsamples = 26\nvalue = 1.014'),
#  Text(0.9109442060085837, 0.5769230769230769, 'x[1] <= 0.99\nsquared_error = 0.001\nsamples = 22\nvalue = 0.998'),
#  Text(0.8927038626609443, 0.5, 'x[1] <= 0.97\nsquared_error = 0.0\nsamples = 9\nvalue = 0.97'),
#  Text(0.8841201716738197, 0.4230769230769231, 'x[7] <= 0.996\nsquared_error = 0.0\nsamples = 5\nvalue = 0.963'),
#  Text(0.8798283261802575, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.96'),
#  Text(0.8884120171673819, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.965'),
#  Text(0.9012875536480687, 0.4230769230769231, 'x[4] <= 0.082\nsquared_error = 0.0\nsamples = 4\nvalue = 0.979'),
#  Text(0.8969957081545065, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.98'),
#  Text(0.9055793991416309, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 0.975'),
#  Text(0.9291845493562232, 0.5, 'x[1] <= 1.015\nsquared_error = 0.0\nsamples = 13\nvalue = 1.018'),
#  Text(0.9184549356223176, 0.4230769230769231, 'x[3] <= 2.2\nsquared_error = 0.0\nsamples = 5\nvalue = 1.003'),
#  Text(0.9141630901287554, 0.34615384615384615, 'x[6] <= 60.0\nsquared_error = 0.0\nsamples = 2\nvalue = 1.007'),
#  Text(0.9098712446351931, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 1.005'),
#  Text(0.9184549356223176, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 1.01'),
#  Text(0.9227467811158798, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.9399141630901288, 0.4230769230769231, 'x[1] <= 1.03\nsquared_error = 0.0\nsamples = 8\nvalue = 1.027'),
#  Text(0.9313304721030042, 0.34615384615384615, 'x[1] <= 1.022\nsquared_error = 0.0\nsamples = 5\nvalue = 1.021'),
#  Text(0.927038626609442, 0.2692307692307692, 'squared_error = 0.0\nsamples = 4\nvalue = 1.02'),
#  Text(0.9356223175965666, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 1.025'),
#  Text(0.9484978540772532, 0.34615384615384615, 'x[6] <= 43.0\nsquared_error = 0.0\nsamples = 3\nvalue = 1.038'),
#  Text(0.944206008583691, 0.2692307692307692, 'squared_error = 0.0\nsamples = 2\nvalue = 1.04'),
#  Text(0.9527896995708155, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 1.035'),
#  Text(0.9613733905579399, 0.5769230769230769, 'x[5] <= 8.5\nsquared_error = 0.001\nsamples = 4\nvalue = 1.101'),
#  Text(0.9527896995708155, 0.5, 'x[1] <= 1.123\nsquared_error = 0.0\nsamples = 2\nvalue = 1.122'),
#  Text(0.9484978540772532, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 1.115'),
#  Text(0.9570815450643777, 0.4230769230769231, 'squared_error = -0.0\nsamples = 1\nvalue = 1.13'),
#  Text(0.9699570815450643, 0.5, 'x[9] <= 0.5\nsquared_error = 0.0\nsamples = 2\nvalue = 1.08'),
#  Text(0.9656652360515021, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 1.09'),
#  Text(0.9742489270386266, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 1.07'),
#  Text(0.9871244635193133, 0.6538461538461539, 'x[7] <= 0.995\nsquared_error = 0.019\nsamples = 6\nvalue = 1.308'),
#  Text(0.9828326180257511, 0.5769230769230769, 'squared_error = 0.0\nsamples = 1\nvalue = 1.58'),
#  Text(0.9914163090128756, 0.5769230769230769, 'x[1] <= 1.285\nsquared_error = 0.004\nsamples = 5\nvalue = 1.253'),
#  Text(0.9871244635193133, 0.5, 'x[10] <= 10.0\nsquared_error = 0.001\nsamples = 3\nvalue = 1.202'),
#  Text(0.9828326180257511, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 1.24'),
#  Text(0.9914163090128756, 0.4230769230769231, 'x[7] <= 0.996\nsquared_error = 0.0\nsamples = 2\nvalue = 1.182'),
#  Text(0.9871244635193133, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 1.18'),
#  Text(0.9957081545064378, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 1.185'),
#  Text(0.9957081545064378, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 1.33')]

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([0.47 , 0.825, 0.29 , 0.645, 0.45 , 0.64 , 0.715, 0.36 , 0.95 ,
#        0.735, 0.52 , 0.68 , 0.5  , 1.035, 0.58 , 0.31 , 0.28 , 0.4  ,
#        0.6  , 0.59 , 0.66 , 0.53 , 0.51 , 0.33 , 0.365, 0.64 , 0.58 ,
#        0.34 , 0.38 , 0.47 , 0.24 , 0.42 , 0.56 , 0.68 , 0.84 , 0.33 ,
#        0.63 , 0.54 , 0.4  , 0.55 , 0.46 , 0.48 , 0.4  , 0.49 , 0.41 ,
#        0.815, 0.57 , 0.36 , 0.52 , 0.28 , 0.45 , 0.32 , 0.41 , 0.47 ,
#        0.31 , 0.6  , 0.53 , 0.63 , 0.36 , 0.58 , 0.67 , 0.41 , 0.44 ,
#        0.36 , 0.66 , 0.44 , 0.695, 0.645, 0.34 , 0.53 , 0.77 , 0.32 ,
#        0.735, 0.51 , 0.48 , 0.49 , 0.57 , 0.34 , 0.5  , 0.39 , 0.48 ,
#        0.39 , 0.44 , 0.29 , 0.64 , 0.67 , 0.39 , 0.655, 0.52 , 0.735,
#        0.52 , 0.61 , 0.58 , 0.58 , 0.27 , 0.77 , 0.27 , 0.5  , 0.55 ,
#        0.36 , 0.32 , 0.27 , 0.635, 0.16 , 0.52 , 0.67 , 0.52 , 0.59 ,
#        0.56 , 0.715, 0.61 , 0.77 , 0.37 , 0.725, 0.77 , 0.45 , 0.53 ,
#        0.4  , 0.76 , 0.51 , 0.58 , 0.5  , 0.46 , 0.5  , 0.66 , 0.37 ,
#        0.43 , 0.41 , 0.21 , 0.39 , 0.35 , 0.69 , 0.5  , 0.58 , 0.18 ,
#        0.47 , 0.415, 0.635, 0.31 , 0.5  , 0.75 , 0.7  , 0.57 , 0.65 ,
#        0.68 , 0.39 , 0.37 , 0.26 , 0.47 , 0.43 , 0.35 , 0.28 , 0.59 ,
#        0.66 , 0.66 , 0.685, 0.58 , 0.645, 0.5  , 0.4  , 0.51 , 0.49 ,
#        0.35 , 0.59 , 0.6  , 0.87 , 0.51 , 0.31 , 0.59 , 0.5  , 0.38 ,
#        0.5  , 0.62 , 0.3  , 0.795, 0.34 , 0.28 , 0.41 , 0.66 , 0.665,
#        0.575, 0.36 , 0.55 , 0.27 , 0.29 , 0.67 , 0.4  , 0.635, 0.69 ,
#        0.32 , 0.5  , 0.54 , 0.49 , 0.42 , 0.59 , 0.56 , 0.52 , 0.825,
#        0.64 , 0.62 , 0.42 , 0.49 , 0.63 , 0.675, 0.67 , 0.6  , 0.74 ,
#        0.365, 0.31 , 0.38 , 0.37 , 0.21 , 0.56 , 0.53 , 0.695, 0.6  ,
#        0.36 , 0.31 , 0.57 , 0.63 , 0.7  , 0.41 , 0.4  , 0.4  , 0.59 ,
#        0.35 , 0.4  , 0.47 , 0.61 , 0.5  , 0.66 , 0.64 , 0.915, 0.5  ,
#        0.38 , 0.59 , 0.39 , 0.31 , 0.36 , 0.52 , 0.61 , 0.77 , 0.69 ,
#        0.705, 0.4  , 0.735, 0.33 , 0.69 , 0.78 , 0.3  , 0.755, 0.7  ,
#        0.775, 0.78 , 0.5  , 0.5  , 0.6  , 0.885, 0.61 , 0.615, 0.69 ,
#        0.34 , 0.55 , 0.4  , 0.685, 0.885, 0.705, 0.64 , 0.5  , 0.18 ,
#        0.31 , 0.43 , 0.42 , 0.52 , 0.5  , 0.67 , 0.24 , 0.58 , 0.22 ,
#        0.53 , 0.59 , 0.29 , 0.43 , 0.45 , 0.26 , 0.59 , 0.34 , 0.56 ,
#        0.34 , 0.41 , 0.43 , 0.96 , 0.22 , 0.43 , 0.76 , 0.69 , 0.36 ,
#        0.49 , 0.725, 0.46 , 0.64 , 0.885, 0.53 , 0.29 , 0.34 , 0.61 ,
#        0.775, 0.795, 0.33 , 0.54 , 0.365, 0.51 , 0.46 , 0.5  , 0.88 ,
#        0.27 , 0.39 , 0.34 , 0.77 , 0.32 ])

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df
# Out:
#      Actual  Predicted
# 0     0.470      0.470
# 1     0.820      0.825
# 2     0.290      0.290
# 3     0.645      0.645
# 4     0.450      0.450
# ..      ...        ...
# 315   0.270      0.270
# 316   0.390      0.390
# 317   0.340      0.340
# 318   0.765      0.770
# 319   0.320      0.320
#
# [320 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error: 1.796875000000024e-06
# Mean Absolute Error: 0.00032812500000009136

# %%
metrics.mean_absolute_error(y_test, y_pred) / np.average(y) * 100
# Out:
# 0.06216601894585166
